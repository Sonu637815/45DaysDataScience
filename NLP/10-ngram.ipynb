# %%
##food good
##food not good

##vocals -- {food,good,not}

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
text = ['this movies was not good']

cv = CountVectorizer(ngram_range=(1, 2))
print(cv.fit_transform(text).toarray())
print(cv.vocabulary_)
print(cv.get_feature_names_out())
# Out:
# [[1 1 1 1 1 1 1 1 1]]
# {'this': 5, 'movies': 1, 'was': 7, 'not': 3, 'good': 0, 'this movies': 6, 'movies was': 2, 'was not': 8, 'not good': 4}
# ['good' 'movies' 'movies was' 'not' 'not good' 'this' 'this movies' 'was'
#  'was not']
