# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\asd\appdata\local\programs\python\python311\lib\site-packages (4.3.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy<2.0,>=1.18.5 in c:\users\asd\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\users\asd\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\asd\appdata\local\programs\python\python311\lib\site-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in c:\users\asd\appdata\local\programs\python\python311\lib\site-packages (from smart-open>=1.8.1->gensim) (1.17.2)

# %%
from gensim.models import Word2Vec

# %%
import gensim.downloader as api

word2vec_model = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
word2vec_model.most_similar("cricket")
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]
