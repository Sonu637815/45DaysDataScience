# %%
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.datasets import make_blobs

# %%
x
# Out:
# array([[ 2.71575802,  8.24684412],
#        [ 3.09614158,  9.01570985],
#        [ 8.4024272 , -1.3964836 ],
#        [ 1.88573302,  8.61035722],
#        [-3.70860847, -6.36567043],
#        [-1.0619763 , -6.99865424],
#        [-1.94939621, -6.52673464],
#        [ 9.31356944, -2.96374194],
#        [ 2.74443285,  9.7709824 ],
#        [ 0.38655233,  7.75818165],
#        [ 0.8984955 , 10.29732405],
#        [ 1.29861265,  8.02361475],
#        [ 2.13058381,  9.19790573],
#        [ 0.25083361,  9.29422207],
#        [-1.06964713, -5.3434504 ],
#        [ 0.49272968,  8.37100469],
#        [ 8.29689535, -0.99471161],
#        [-0.55984236, -4.90179719],
#        [-2.29341717, -4.96695771],
#        [ 7.98436687, -2.26862804],
#        [ 1.67841902,  8.44184589],
#        [ 8.11415972,  0.03921697],
#        [-1.58676514, -4.42209101],
#        [ 9.17392376,  0.53856628],
#        [ 9.51035245, -2.01079785],
#        [ 0.58932051,  7.79713149],
#        [ 0.95230976, 10.2263368 ],
#        [ 7.66154158, -0.71541124],
#        [ 1.87169532,  9.9012959 ],
#        [ 1.755309  , 10.28227507],
#        [ 8.85986708, -2.38472148],
#        [ 2.76501256,  9.62188402],
#        [-1.69456697, -5.37229368],
#        [ 8.0695054 , -0.07897938],
#        [-0.40058095,  9.42697608],
#        [-0.17206291, -6.15752206],
#        [-2.6277247 , -3.37391053],
#        [ 9.48112149, -1.58602268],
#        [ 9.2955185 , -2.13110986],
#        [-2.81953475, -4.73404194],
#        [-1.72751978, -8.08085691],
#        [-2.01138444, -3.98949551],
#        [-1.76036472, -5.85539877],
#        [-2.82420666, -3.2810988 ],
#        [ 8.62138401, -3.23441688],
#        [ 9.94365331, -1.17120444],
#        [ 9.37989383, -2.40829107],
#        [ 1.64056972,  8.34249302],
#        [ 0.86698518,  8.66466087],
#        [-0.52485915, -5.31877452],
#        [ 8.22048768, -4.38280063],
#        [-2.32951093, -5.23825551],
#        [ 9.52160429, -2.42976894],
#        [ 0.78930299,  8.07137118],
#        [-1.0946071 , -4.05535465],
#        [-1.73695362, -4.9042144 ],
#        [ 0.07925158,  8.94963538],
#        [ 1.67760132,  9.08390717],
#        [-1.37776069, -5.27974543],
#        [ 8.89279007, -4.15835851],
#        [-0.80420494,  9.98656024],
#        [10.3232163 , -2.9810317 ],
#        [ 8.58640271, -2.60839713],
#        [-2.62205593, -6.6255919 ],
#        [ 0.43201858,  8.66942545],
#        [-3.06911317, -5.81733132],
#        [ 0.34195503,  8.49247109],
#        [-2.89673965, -4.59422517],
#        [ 8.00352776, -3.88190361],
#        [ 0.191901  ,  9.5038158 ],
#        [-2.31943548, -5.46838054],
#        [ 0.24863759,  9.21183627],
#        [ 8.72496878, -2.50078772],
#        [ 9.12782078, -1.69324079],
#        [ 9.74351603, -2.66725053],
#        [ 8.36815311, -3.55956101],
#        [-3.00706574, -6.87847166],
#        [ 1.64142785,  7.20249645],
#        [10.37300057, -2.50447948],
#        [ 1.23740291,  9.18401046],
#        [ 7.94805681, -2.67088654],
#        [-2.3647639 , -5.72004599],
#        [ 7.71611568, -3.18807758],
#        [ 0.36555782, 10.18722041],
#        [10.31075466, -2.80622235],
#        [10.86711957, -3.45918936],
#        [-0.4327671 , -4.30760061],
#        [10.20857237, -1.92253414],
#        [ 3.35342324,  7.38472281],
#        [ 0.88621398,  7.72818341],
#        [-1.28032938, -5.46036854],
#        [-2.67767091, -5.60068144],
#        [ 2.5811195 ,  8.19595934],
#        [10.07503036, -3.13035204],
#        [-1.0527991 , -6.18826057],
#        [-3.56315196, -4.27045062],
#        [ 8.47084237, -3.35797123],
#        [-2.14373246, -5.31508312],
#        [-2.8396572 , -6.08487418],
#        [ 8.84226923, -2.94980249]])

# %%
#create synthethic data
x , _ = make_blobs(n_samples=100,centers=3,cluster_std=1.0)

# %%
model = AgglomerativeClustering(n_clusters=3,linkage='ward')
labels = model.fit_predict(x)

# %%
#dendogram
linked = linkage(x,method="ward")
plt.figure(figsize=(10,6))
dendrogram(linked)
plt.xticks(rotation=90)
plt.show()
